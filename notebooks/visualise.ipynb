# %%
from app.env import MarketEnv
from app.config import Config
env = MarketEnv(csv_name=Config.data["file_name"], window_size=Config.model["window_size"], verbose=1, save_folder="artifacts/test")

# %%
env.render()
